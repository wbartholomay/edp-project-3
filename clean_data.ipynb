# %%
! pip install pyarrow
! pip install fastparquet
# Out:
# Collecting pyarrow
#   Downloading pyarrow-16.1.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyarrow) (1.26.4)
# Downloading pyarrow-16.1.0-cp311-cp311-win_amd64.whl (25.9 MB)
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/25.9 MB 1.3 MB/s eta 0:00:20
#    - -------------------------------------- 0.8/25.9 MB 6.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.0/25.9 MB 17.6 MB/s eta 0:00:02
#    ------------ --------------------------- 8.3/25.9 MB 40.9 MB/s eta 0:00:01
#    --------------------- ------------------ 13.7/25.9 MB 110.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 15.4/25.9 MB 131.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.8/25.9 MB 93.9 MB/s eta 0:00:01
#    -------------------------------------- - 25.1/25.9 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 25.9/25.9 MB 81.8 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-16.1.0
# DEPRECATION: Loading egg at c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages\matlabengine-23.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\Will\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastparquet) (2.2.2)
# Requirement already satisfied: numpy in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.8.3-cp311-none-win_amd64.whl.metadata (4.3 kB)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fastparquet) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.5.0->fastparquet) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Downloading fastparquet-2024.5.0-cp311-cp311-win_amd64.whl (671 kB)
#    ---------------------------------------- 0.0/672.0 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/672.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 583.7/672.0 kB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 672.0/672.0 kB 8.5 MB/s eta 0:00:00
# Downloading cramjam-2.8.3-cp311-none-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 101.8 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ---------------------------------------- 0.0/177.6 kB ? eta -:--:--
#    ---------------------------------------- 177.6/177.6 kB ? eta 0:00:00
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.8.3 fastparquet-2024.5.0 fsspec-2024.6.1
# DEPRECATION: Loading egg at c:\users\will\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages\matlabengine-23.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\Will\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('troop_movements10m.csv')

display(data)
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000        invalid_unit         NaN
#
#          location_y  destination_x  destination_y    homeworld
# 0               8.0              1              1  Glee Anselm
# 1               4.0              0              1    Trandosha
# 2               3.0              6              1     Corellia
# 3               1.0              6              9        Shili
# 4               4.0              9              6   Muunilinst
# ...             ...            ...            ...          ...
# 9999995         6.0              1              3      Troiken
# 9999996         6.0              2              0     Kashyyyk
# 9999997         7.0              6              4     Kashyyyk
# 9999998         6.0              8              8        Kalee
# 9999999         NaN              3              0        Skako
#
# [10000000 rows x 8 columns]

# %%
data['unit_type'] = data['unit_type'].apply(lambda x : "Unknown" if x == "invalid_unit" else x)
display(data)
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000             Unknown         NaN
#
#          location_y  destination_x  destination_y    homeworld
# 0               8.0              1              1  Glee Anselm
# 1               4.0              0              1    Trandosha
# 2               3.0              6              1     Corellia
# 3               1.0              6              9        Shili
# 4               4.0              9              6   Muunilinst
# ...             ...            ...            ...          ...
# 9999995         6.0              1              3      Troiken
# 9999996         6.0              2              0     Kashyyyk
# 9999997         7.0              6              4     Kashyyyk
# 9999998         6.0              8              8        Kalee
# 9999999         NaN              3              0        Skako
#
# [10000000 rows x 8 columns]

# %%
data = data.ffill()
display(data)
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000             Unknown         6.0
#
#          location_y  destination_x  destination_y    homeworld
# 0               8.0              1              1  Glee Anselm
# 1               4.0              0              1    Trandosha
# 2               3.0              6              1     Corellia
# 3               1.0              6              9        Shili
# 4               4.0              9              6   Muunilinst
# ...             ...            ...            ...          ...
# 9999995         6.0              1              3      Troiken
# 9999996         6.0              2              0     Kashyyyk
# 9999997         7.0              6              4     Kashyyyk
# 9999998         6.0              8              8        Kalee
# 9999999         6.0              3              0        Skako
#
# [10000000 rows x 8 columns]

# %%
data.to_parquet("troop_movements10m.parquet")
